# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
# Import the data
our_data = pd.read_csv("insurance.csv")
our_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# The iloc function allows use to select rows from the dataframe for plotting.  
x = our_data.iloc[:,:1].values
y = our_data.iloc[:,-1].values

plt.scatter(x,y,color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
# Exploring wether the grouping in the data correlates to other available variables
variable_check = our_data[our_data.smoker == 'yes']
variable_check

x = southwest.iloc[:,:1].values
y = southwest.iloc[:,-1].values

plt.scatter(x,y,color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
# Fit the model
our_data = LinearRegression()
our_data.fit(x,y)
# Out:
# LinearRegression()

# %%
# Plot the data and model
y_pred = our_data.predict(x)

plt.scatter(x,y,color = 'b')
plt.plot(x,y_pred,color = 'r')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
# Predict an unknown value
unk_x = [[45]] 

x_pred = np.append(x, unk_x).reshape(-1,1)
y_pred = our_data.predict(x_pred)

plt.scatter(x,y,color = 'b')
plt.plot(x_pred,y_pred,color = 'r')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

print("Employee salary should be:", our_data.predict(unk_x))
# Out:
# Employee salary should be: [34029.82022186]
